# %%
import numpy
from math import *
from matplotlib import pyplot
# %matplotlib inline
from scipy.special import erf

# %%
l = 0.001
nx = 100
dx = l/nx
alpha2 = 0.17*10**-6
t = 0.1
alpha1 = 2.06*10**-5
Cp = 2030
Tw = 383.15
Tsat = 373.15

# %%
chi = 0.0669161

# %%
T = numpy.zeros((nx,1),dtype=float)
T[:] = Tsat
t= numpy.linspace(0.00,0.1,nx)
XI = 2*chi*(numpy.sqrt(alpha1*t))
pyplot.plot (t,XI)
pyplot.xlim([0.,0.1])
# Out:
# (0.0, 0.1)

# %%
T = Tw  + (Tsat-Tw)/erf(chi)*erf(chi/2*numpy.sqrt(alpha1*t))

# %%
pyplot.plot (XI,T)
pyplot.xlim([0.,0.00025])
# Out:
# (0.0, 0.00025)
